png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4139.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4140.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4141.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4142.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4143.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4144.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4145.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4146.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4147.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4148.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4149.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4150.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4151.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4152.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4153.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4154.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4155.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4156.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4157.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4158.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4159.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4160.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4161.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4162.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4163.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4164.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4165.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4166.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4167.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4168.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4169.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4170.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4171.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4172.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4173.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4174.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4175.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4176.png
#   inflating: COVID-19_Lung_CT_Scans/COVID-19/COVID-19_4177.png
# ...
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_723.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_724.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_725.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_726.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_727.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_728.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_729.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_730.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_731.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_732.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_733.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_734.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_735.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_736.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_737.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_738.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_739.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_740.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_741.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_742.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_743.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_744.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_745.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_746.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_747.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_748.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_749.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_750.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_751.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_752.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_753.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_754.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_755.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_756.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_757.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_758.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_759.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_760.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_761.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_762.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_763.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_764.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_765.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_766.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_767.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_768.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_769.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_770.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_771.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_772.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_773.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_774.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_775.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_776.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_777.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_778.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_779.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_780.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_781.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_782.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_783.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_784.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_785.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_786.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_787.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_788.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_789.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_790.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_791.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_792.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_793.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_794.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_795.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_796.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_797.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_798.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_799.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_800.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_801.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_802.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_803.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_804.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_805.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_806.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_807.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_808.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_809.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_810.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_811.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_812.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_813.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_814.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_815.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_816.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_817.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_818.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_819.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_820.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_821.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_822.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_823.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_824.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_825.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_826.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_827.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_828.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_829.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_830.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_831.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_832.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_833.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_834.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_835.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_836.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_837.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_838.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_839.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_840.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_841.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_842.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_843.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_844.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_845.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_846.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_847.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_848.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_849.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_850.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_851.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_852.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_853.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_854.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_855.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_856.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_857.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_858.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_859.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_860.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_861.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_862.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_863.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_864.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_865.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_866.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_867.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_868.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_869.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_870.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_871.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_872.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_873.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_874.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_875.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_876.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_877.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_878.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_879.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_880.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_881.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_882.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_883.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_884.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_885.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_886.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_887.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_888.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_889.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_890.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_891.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_892.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_893.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_894.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_895.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_896.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_897.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_898.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_899.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_900.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_901.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_902.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_903.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_904.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_905.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_906.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_907.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_908.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_909.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_910.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_911.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_912.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_913.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_914.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_915.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_916.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_917.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_918.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_919.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_920.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_921.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_922.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_923.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_924.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_925.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_926.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_927.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_928.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_929.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_930.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_931.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_932.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_933.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_934.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_935.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_936.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_937.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_938.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_939.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_940.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_941.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_942.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_943.png
#   inflating: COVID-19_Lung_CT_Scans/Non-COVID-19/Non-COVID-19_944.png

# %%
# !rm COVID-19_Lung_CT_Scans/COVID-19/desktop.ini

# %% [markdown]
# # 1.prepair the dataset of covid

# %%
import torch

from torch.utils.data import Dataset, DataLoader

from torch.utils.data import Dataset

from PIL import Image


torch.cuda.empty_cache()




import os
def r_txt(txt_path):
    txt_data=[]
    for file_name in os.listdir(txt_path):
        txt_data.append(file_name)
    # with open(txt_path) as f:
    #     lines = f.readlines()
    # txt_data = [line.strip() for line in lines]
    return txt_data


class CovidCTDataset(Dataset):
    def __init__(self, root_dir, txt_COVID, txt_NonCOVID, transform=None):

        self.root_dir = root_dir
        self.txt_path = [txt_COVID, txt_NonCOVID]
        self.classes = ['COVID-19', 'Non-COVID-19']
        self.num_cls = len(self.classes)
        self.img_list = []
        for c in range(self.num_cls):
            cls_list = [[os.path.join(self.root_dir, self.classes[c], item), c] for item in r_txt(self.txt_path[c])]
            self.img_list += cls_list
        self.transform = transform
        # print("img_list",self.img_list)

    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_path = self.img_list[idx][0]
        image = Image.open(img_path).convert('L')

        if self.transform:
            image = self.transform(image)
        sample = {'img': image,
                  'label': int(self.img_list[idx][1])}
        # print("sample",sample)
        return image, int(self.img_list[idx][1])

# %% [markdown]
# # 2. complex CNN import

# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Module, Parameter, init
from torch.nn import Conv2d, Linear, BatchNorm2d
from torch.nn.functional import relu
from torchvision import datasets, transforms

# %% [markdown]
# ## 2.1 linear function

# %%
class linear_function(Module):

    def __init__(self, i_f, o_f):
        super(linear_function, self).__init__()
        self.fc_r = Linear(i_f, o_f)
        self.fc_i = Linear(i_f, o_f)

    def forward(self, r, i):
        return self.fc_r(r) - self.fc_i(i), self.fc_r(i) + self.fc_i(r)

# %% [markdown]
# ## 2.2 construct Conv2d ，it has two layers ,r and i parts

# %%
class CC2d(Module):

    def __init__(self, i_c, o_c, kernel_size=3, stride=1, padding=0,
                 dilation=1, g=1, bias=True):
        super(CC2d, self).__init__()
        self.c_r = Conv2d(i_c, o_c, kernel_size, stride, padding, dilation, g, bias)
        self.c_i = Conv2d(i_c, o_c, kernel_size, stride, padding, dilation, g, bias)

    def forward(self, r, i):
        assert (r.size() == i.size())
        return self.c_r(r) - self.c_i(i), self.c_r(i) + self.c_i(r)

# %% [markdown]
# ## 2.3 batch norm

# %%
class batch_norm(Module):

    def __init__(self, n_f, ep=1e-5, mom=0.1, af=True,
                 stats=True):
        super(batch_norm, self).__init__()

        self.af = af
        self.stats = stats

        self.n_f = n_f
        self.ep = ep
        self.mom = mom
        if self.af:
#comment one and use one, can change from these two, two methods of weight initialization
  #--------------------------------------------------------------------------------------------
            #this is using Tensor Parameter for weight initialization
            #self.weight = Parameter(torch.Tensor(n_f, 3))
            #self.bias = Parameter(torch.Tensor(n_f, 2))
  #---------------------------------------------------------------------------------------------
            #this is using Linear for weight initialization
            self.weight = torch.nn.Linear(3, n_f).weight
            self.bias = torch.nn.Linear(2, n_f).weight
        else:
            self.register_parameter('weight', None)
            self.register_parameter('bias', None)
        if self.stats:
            self.register_buffer('running_mean', torch.zeros(n_f, 2))
            self.register_buffer('running_covar', torch.zeros(n_f, 3))
            self.running_covar[:, 0] = 1.4142135623730951
            self.running_covar[:, 1] = 1.4142135623730951
            self.register_buffer('num_batches_tracked', torch.tensor(0, dtype=torch.long))
        else:
            self.register_parameter('running_mean', None)
            self.register_parameter('running_covar', None)
            self.register_parameter('num_batches_tracked', None)
        self.reset_parameters()

    def reset_running_stats(self):
        if self.stats:
            self.running_mean.zero_()
            self.running_covar.zero_()
            self.running_covar[:, 0] = 1.4142135623730951
            self.running_covar[:, 1] = 1.4142135623730951
            self.num_batches_tracked.zero_()

    def reset_parameters(self):
        self.reset_running_stats()
        if self.af:
            init.constant_(self.weight[:, :2], 1.4142135623730951)
            init.zeros_(self.weight[:, 2])
            init.zeros_(self.bias)

# %%
class batch_norm2d(batch_norm):

    def forward(self, r, i):

        expo = 0.0

        if self.training and self.stats:
            if self.num_batches_tracked is not None:
                self.num_batches_tracked += 1
                if self.mom is None:  # use cumulative moving average
                    expo = 1.0 / float(self.num_batches_tracked)
                else:  # use exponential moving average
                    expo = self.mom

        if self.training:

            # calculate mean of real and imaginary part
            real_mean = r.mean([0, 2, 3])
            i_mean = i.mean([0, 2, 3])

            mean = torch.stack((real_mean, i_mean), dim=1)

            # update running mean
            with torch.no_grad():
                self.running_mean = expo * mean \
                                    + (1 - expo) * self.running_mean

            r = r - real_mean[None, :, None, None]
            i = i - i_mean[None, :, None, None]

            # Elements of the covariance matrix (biased for train)
            n = r.numel() / r.size(1)
            RR = 1. / n * r.pow(2).sum(dim=[0, 2, 3]) + self.ep
            II = 1. / n * i.pow(2).sum(dim=[0, 2, 3]) + self.ep
            RI = (r.mul(i)).mean(dim=[0, 2, 3])

            with torch.no_grad():
                self.running_covar[:, 0] = expo * RR * n / (n - 1) \
                                           + (1 - expo) * self.running_covar[:, 0]

                self.running_covar[:, 1] = expo * II * n / (n - 1) \
                                           + (1 - expo) * self.running_covar[:, 1]

                self.running_covar[:, 2] = expo * RI * n / (n - 1) \
                                           + (1 - expo) * self.running_covar[:, 2]

        else:
            mean = self.running_mean
            RR = self.running_covar[:, 0] + self.ep
            II = self.running_covar[:, 1] + self.ep
            RI = self.running_covar[:, 2]  # +self.ep

            r = r - mean[None, :, 0, None, None]
            i = i - mean[None, :, 1, None, None]

        # calculate the inverse square root the covariance matrix
        c = RR * II - RI.pow(2)
        s = torch.sqrt(c)
        t = torch.sqrt(II + RR + 2 * s)
        inv_st = 1.0 / (s * t)
        R_rr = (II + s) * inv_st
        R_II = (RR + s) * inv_st
        R_RI = -RI * inv_st

        r, i = R_rr[None, :, None, None] * r + R_RI[None, :, None, None] * i, \
                           R_II[None, :, None, None] * i + R_RI[None, :, None, None] * r

        if self.af:
            r, i = self.weight[None, :, 0, None, None] * r + self.weight[None, :, 2, None,
                                                                               None] * i + \
                               self.bias[None, :, 0, None, None], \
                               self.weight[None, :, 2, None, None] * r + self.weight[None, :, 1, None,
                                                                               None] * i + \
                               self.bias[None, :, 1, None, None]

        return r, i

# %% [markdown]
# # 3 define the complex cnn model

# %%
class Model_complex(nn.Module):

    def __init__(self):
        super(Model_complex, self).__init__()
        self.conv1 = CC2d(1, 20, 5, 2)
        self.bn = batch_norm2d(20)
        self.conv2 = CC2d(20, 50, 5, 2)
        self.fc1 = linear_function(4 * 4 * 50, 500)
        self.fc2 = linear_function(500, 10)

        self.img = BatchNorm2d(1)
        self.conimg = Conv2d(1, 1, 3, 1, padding=1)

    def forward(self, x):
        X_R = x
        # imaginary part BN-ReLU-Conv-BN-ReLU-Conv as shown in paper
        X_I = self.img(X_R)
        X_I = relu(X_I)
        X_I = self.conimg(X_I)

        # flow into complex net
        X_R, X_I = self.conv1(X_R, X_I)
        X_R = relu(X_R)
        X_I = relu(X_I)
        X_R, X_I = self.bn(X_R, X_I)
        X_R, X_I = self.conv2(X_R, X_I)
        X_R = relu(X_R)
        X_I = relu(X_I)
        #         print(X_R.shape)
        X_R = X_R.reshape(-1, 4 * 4 * 50)
        X_I = X_I.reshape(-1, 4 * 4 * 50)
        X_R, X_I = self.fc1(X_R, X_I)
        X_R = relu(X_R)
        X_I = relu(X_I)
        X_R, X_I = self.fc2(X_R, X_I)
        x = torch.sqrt(torch.pow(X_R, 2) + torch.pow(X_I, 2))
        return F.log_softmax(x, dim=1)

# %% [markdown]
# # 4 train complex cnn model

# %%
if __name__ == '__main__':

    trans = transforms.Compose([
        transforms.Resize(28),
        transforms.CenterCrop(28),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (1.0,))
    ])
    #"C:\Users\86130\Downloads\COVID-CT-master (1)\COVID-CT-master\covid19-lung-ct-scans\COVID-19_Lung_CT_Scans\COVID-19"
    #"C:\Users\86130\Downloads\COVID-CT-master (1)\COVID-CT-master\covid19-lung-ct-scans\COVID-19_Lung_CT_Scans"
    trainset = CovidCTDataset(root_dir='COVID-19_Lung_CT_Scans',
                              txt_COVID='COVID-19_Lung_CT_Scans/COVID-19',
                              txt_NonCOVID='COVID-19_Lung_CT_Scans/Non-COVID-19',
                              transform=trans)
    # valset = CovidCTDataset(root_dir='../../Images-processed',
    #                         txt_COVID='../../Data-split/COVID/valCT_COVID.txt',
    #                         txt_NonCOVID='../../Data-split/NonCOVID/valCT_NonCOVID.txt',
    #                         transform=trans)
    # testset = CovidCTDataset(root_dir='../../Images-processed',
    #                          txt_COVID='../../Data-split/COVID/testCT_COVID.txt',
    #                          txt_NonCOVID='../../Data-split/NonCOVID/testCT_NonCOVID.txt',
    #                          transform=trans)
    print(trainset.__len__())
    # print(valset.__len__())
    # print(testset.__len__())

    batchsize = 16
    trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (1.0,))])
    # train_set = datasets.MNIST('../data', train=True, transform=trans, download=True)
    # test_set = datasets.MNIST('../data', train=False, transform=trans, download=True)
    # train_loader = torch.utils.data.DataLoader(train_set, batch_size=batchsize, shuffle=True)
    # test_loader = torch.utils.data.DataLoader(test_set, batch_size=batchsize, shuffle=True)

    train_loader = DataLoader(trainset, batch_size=batchsize, drop_last=False, shuffle=True)
    # val_loader = DataLoader(valset, batch_size=batchsize, drop_last=False, shuffle=False)
    # test_loader = DataLoader(testset, batch_size=batchsize, drop_last=False, shuffle=False)

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model = Model_complex().to(device)
    print(model)

    optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

    # train step
    train_loss = []
    for epoch in range(5):
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            # print("data",data)
            # print(data.shape)
            # print("target",target)
            # print(target.shape)
            # print("batch_idx",batch_idx,"tata",len(data))

            optimizer.zero_grad()
            output = model(data)
            loss = F.nll_loss(output, target)
            loss.backward()
            optimizer.step()
            train_loss.append(loss.item())
            if batch_idx % 100 == 0:
                print('Train Epoch: {:3} [{:6}/{:6} ({:3.0f}%)]\tLoss: {:.6f}'.format(
                    epoch,
                    batch_idx * len(data),
                    len(train_loader.dataset),
                    100. * batch_idx / len(train_loader),
                    loss.item())
                )

    plt.plot(train_loss)
    plt.show()
# Out:
# 8439
# Model_complex(
#   (conv1): CC2d(
#     (c_r): Conv2d(1, 20, kernel_size=(5, 5), stride=(2, 2))
#     (c_i): Conv2d(1, 20, kernel_size=(5, 5), stride=(2, 2))
#   )
#   (bn): batch_norm2d()
#   (conv2): CC2d(
#     (c_r): Conv2d(20, 50, kernel_size=(5, 5), stride=(2, 2))
#     (c_i): Conv2d(20, 50, kernel_size=(5, 5), stride=(2, 2))
#   )
#   (fc1): linear_function(
#     (fc_r): Linear(in_features=800, out_features=500, bias=True)
#     (fc_i): Linear(in_features=800, out_features=500, bias=True)
#   )
#   (fc2): linear_function(
#     (fc_r): Linear(in_features=500, out_features=10, bias=True)
#     (fc_i): Linear(in_features=500, out_features=10, bias=True)
#   )
#   (img): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (
def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)

        x = x.view(x.size()[0], -1)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        return x

# %%
import torch.optim as optim
if __name__ == '__main__':

    trans = transforms.Compose([
        transforms.Resize(28),
        transforms.CenterCrop(28),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (1.0,))
    ])
    #"C:\Users\86130\Downloads\COVID-CT-master (1)\COVID-CT-master\covid19-lung-ct-scans\COVID-19_Lung_CT_Scans\COVID-19"
    #"C:\Users\86130\Downloads\COVID-CT-master (1)\COVID-CT-master\covid19-lung-ct-scans\COVID-19_Lung_CT_Scans"
    trainset = CovidCTDataset(root_dir='COVID-19_Lung_CT_Scans',
                              txt_COVID='COVID-19_Lung_CT_Scans/COVID-19',
                              txt_NonCOVID='COVID-19_Lung_CT_Scans/Non-COVID-19',
                              transform=trans)
    # valset = CovidCTDataset(root_dir='../../Images-processed',
    #                         txt_COVID='../../Data-split/COVID/valCT_COVID.txt',
    #                         txt_NonCOVID='../../Data-split/NonCOVID/valCT_NonCOVID.txt',
    #                         transform=trans)
    # testset = CovidCTDataset(root_dir='../../Images-processed',
    #                          txt_COVID='../../Data-split/COVID/testCT_COVID.txt',
    #                          txt_NonCOVID='../../Data-split/NonCOVID/testCT_NonCOVID.txt',
    #                          transform=trans)
    print(trainset.__len__())
    # print(valset.__len__())
    # print(testset.__len__())

    batchsize = 16
    trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (1.0,))])
    # train_set = datasets.MNIST('../data', train=True, transform=trans, download=True)
    # test_set = datasets.MNIST('../data', train=False, transform=trans, download=True)
    # train_loader = torch.utils.data.DataLoader(train_set, batch_size=batchsize, shuffle=True)
    # test_loader = torch.utils.data.DataLoader(test_set, batch_size=batchsize, shuffle=True)

    train_loader = DataLoader(trainset, batch_size=batchsize, drop_last=False, shuffle=True)
    # val_loader = DataLoader(valset, batch_size=batchsize, drop_last=False, shuffle=False)
    # test_loader = DataLoader(testset, batch_size=batchsize, drop_last=False, shuffle=False)

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net = LeNet5().to(device)

    criterion = nn.CrossEntropyLoss()  # cross entropy loss always use for classfication
    optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

    # training

    train_loss = []
    for epoch in range(5):
        sum_loss = 0.0
        # read the data
        for i, data in enumerate(train_loader):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the dradient
            optimizer.zero_grad()

            # forward + backward
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss.append(loss.item())

            # for every 100 batch training print mean loss once
            sum_loss += loss.item()
            if i % 100 == 99:
                print('[%d, %d] loss: %.03f'
                      % (epoch + 1, i + 1, sum_loss / 100))
                sum_loss = 0.0
    plt.plot(train_loss)
    plt.show()
# Out:
# 8439
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# [1, 100] loss: 0.747
# [1, 200] loss: 0.343
# [1, 300] loss: 0.345
# [1, 400] loss: 0.350
# [1, 500] loss: 0.361
# [2, 100] loss: 0.313
# [2, 200] loss: 0.266
# [2, 300] loss: 0.281
# [2, 400] loss: 0.265
# [2, 500] loss: 0.271
# [3, 100] loss: 0.216
# [3, 200] loss: 0.269
# [3, 300] loss: 0.210
# [3, 400] loss: 0.239
# [3, 500] loss: 0.193
# [4, 100] loss: 0.199
# [4, 200] loss: 0.170
# [4, 300] loss: 0.144
# [4, 400] loss: 0.174
# [4, 500] loss: 0.168
# [5, 100] loss: 0.131
# [5, 200] loss: 0.146
# [5, 300] loss: 0.135
# [5, 400] loss: 0.097
# [5, 500] loss: 0.107
